# %% [markdown]
# # Interview Questions Mailed By A Data Analytics Company 🏢

# %%
# import pandas as pd   - to import pandas library

# %%
import pandas as pd

# %% [markdown]
# # Q-1:

# %% [markdown]
# # Load the dataset into the pandas dataframe, name the variable as a 'survey'

# %%
survey=pd.read_csv("D:\DA-2023\DATA LOVERS PROJECT\Survey Dataset - Technical Interview.csv")  # load data here

# %%
survey.head()                                               # show dataset here
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied  36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied  22   Male
#
#    assembly_no category    weight
# ...

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %% [markdown]
# # Q-2:

# %% [markdown]
# # How many samples were collected on each day?

# %%
 survey.head(2)                                       # survey.head(2)  - to show the first 2 rows of data
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
survey['collection_date'].unique()          # survey['collection_data'].unique() to show all the unique values of a column
# Out:
# array(['5-24-2017', '5-25-2017', '5-26-2017', '5-27-2017', '5-28-2017',
#        '5-29-2017', '5-30-2017', '5-31-2017', '6-1-2017'], dtype=object)

# %%
survey['collection_date'].nunique()                    # survey['collection_date'].nunique()   -- to show total number of unique values in a column
# Out:
# 9

# %%
         survey['collection_date'].value_counts()      # survey['collection_date'].value_counts()  -- to show all the unique values of a column with their counts
# Out:
# 5-24-2017    1479
# 5-25-2017     998
# 5-28-2017     761
# 5-27-2017     665
# 5-29-2017     620
# 6-1-2017      607
# 5-26-2017     598
# 5-30-2017     582
# 5-31-2017     557
# Name: collection_date, dtype: int64

# %%
survey['collection_date'].value_counts(ascending=True)                         # survey['collection_date'].value_counts(ascending=True)
# Out:
# 5-31-2017     557
# 5-30-2017     582
# 5-26-2017     598
# 6-1-2017      607
# 5-29-2017     620
# 5-27-2017     665
# 5-28-2017     761
# 5-25-2017     998
# 5-24-2017    1479
# Name: collection_date, dtype: int64

# %% [markdown]
# # A-3:

# %% [markdown]
# # What proportion of the total respondents were aged less than 45?

# %%
survey.head(2)                      # survey.head(2) --- to show the top 2 records(row)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
survey['age']                    # survey['age']<45 -- filtering on condition basis
# Out:
# 0       26
# 1       34
# 2       25
# 3       36
# 4       22
#         ..
# 6862    25
# 6863    30
# 6864    20
# 6865    23
# 6866    33
# Name: age, Length: 6867, dtype: object

# %%
survey.age.dtype                      # survey.age.dtype -- to check the data type
# Out:
# dtype('O')

# %%
survey.age.unique()                       # survey.age.unique  -- to show all unique values of a column
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey.age.value_counts()                        # # survey.age.value_counts()   --- to show all unique values of a column with their counts
# Out:
# 25      598
# 24      449
# 30      440
# 28      396
# 22      392
# 26      389
# 27      360
# 20      328
# 23      317
# 21      311
# 32      263
# 35      263
# 29      239
# 40      177
# 34      173
# 19      171
# 31      159
# 33      143
# 38      135
# 36      127
# 18      125
# 42      104
# 37       90
# 45       82
# 43       72
# 39       69
# 50       60
# 41       54
# 44       54
# 48       35
# 47       34
# 46       32
# 49       27
# 52       24
# 51       23
# 55       20
# 60       15
# 53       12
# 61       12
# 54       11
# 57       10
# 56        9
# 58        9
# 64        8
# 67        7
# 62        5
# 59        5
# 65        5
# 68        4
# 63        4
# 66        4
# 70        3
# 71        2
# 74        1
# 24ko      1
# 69        1
# 99        1
# 72        1
# 75        1
# 76        1
# Name: age, dtype: int64

# %%
survey['age'].replace({'24ko':24})                        # survey['age'].replace({'24ko': 24})
# Out:
# 0       26
# 1       34
# 2       25
# 3       36
# 4       22
#         ..
# 6862    25
# 6863    30
# 6864    20
# 6865    23
# 6866    33
# Name: age, Length: 6867, dtype: object

# %%
survey['age'].replace({'24ko':24}, inplace=True)                        # survey['age'].replace({'24ko': 24}, inplace=True)

# %%
survey.age.unique()                        # survey.age.unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', 24, '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
survey.age.value_counts()                        # survey.age.value_counts()
# Out:
# 25    598
# 24    449
# 30    440
# 28    396
# 22    392
# 26    389
# 27    360
# 20    328
# 23    317
# 21    311
# 32    263
# 35    263
# 29    239
# 40    177
# 34    173
# 19    171
# 31    159
# 33    143
# 38    135
# 36    127
# 18    125
# 42    104
# 37     90
# 45     82
# 43     72
# 39     69
# 50     60
# 41     54
# 44     54
# 48     35
# 47     34
# 46     32
# 49     27
# 52     24
# 51     23
# 55     20
# 60     15
# 53     12
# 61     12
# 54     11
# 57     10
# 56      9
# 58      9
# 64      8
# 67      7
# 62      5
# 59      5
# 65      5
# 68      4
# 63      4
# 66      4
# 70      3
# 71      2
# 74      1
# 24      1
# 69      1
# 99      1
# 72      1
# 75      1
# 76      1
# Name: age, dtype: int64

# %%
survey['age']=survey.age.astype(int)     # survey['age']=survey.age.astype(int) -- to change the data type of a column

# %%
survey.age.dtype                        # survey.age.dtype
# Out:
# dtype('int32')

# %%
survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
survey[survey['age']<45]
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
6399/6867*100
# Out:
# 93.18479685452162

# %% [markdown]
# # Q-4: Create a new column in the DataFrame "age-group". This column should be contain the age group the respondend
#     belongs to. The age groups are 18-25,25-40,40-45 & 55+, The dataframe should look like as per given

# %%
survey.head(2)                         # survey.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419

# %%
data=survey.copy()                        # data=survey.copy() --to make a copy of dataframe

# %%
data.head()            # data.head(|)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied   34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied   25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied   36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied   22   Male
#
#    assembly_no category    weight
# ...

# %%
#data1=data.insert(10,'age_group',survey.age)   # df_name.insert('new_column position','new column name','new column values')   -- to insert a new columnat required
                            # data.insert(10, 'age_group', survey.age)

# %%
# del data['age_group']  # For delete any column with use condition

# %%
data.head(1)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age gender  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969

# %%
 data1=data.insert(10,'age_group',survey.age)

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age  age_group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26         26
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34         34
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419

# %%
data.head(2)  # Now problem was sorted and now I can continue***********
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
#
#   Vote_Now Past_Vote     CM_satisfaction    MLA_satisfaction  age  age_group  \
# 0      BJP       BJP  Fully Dissatisfied  Fully Dissatisfied   26         26
# 1     RLSP     JD(U)  Somewhat Satisfied  Fully Dissatisfied   34         34
#
#   gender  assembly_no category    weight
# 0   Male          211      Gen  0.346969
# 1   Male          189       BC  0.603419

# %%
data=data[(data.age_group >= 18) & (data.age_group < 25)]   # data1=data[(data.age_group>=18) & (data.age_group<25)]--filtering with & operator

# %%
data.head(2)       # data1.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8            9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age  age_group  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22         22
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied   23         23
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505
# 8   Male          181      Gen  0.226477

# %%
data.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8            9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age  age_group  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22         22
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied   23         23
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505
# 8   Male          181      Gen  0.226477

# %%
data1=data.copy()

# %%
data1.age_group.unique()                        # data1.age_group.unique()
# Out:
# array([22, 23, 24, 19, 21, 18, 20])

# %%
data1['age_group']='18-25'

# %%
data1.head(2)
# Out:
#    response_id collection_date urban_rural  education               income  \
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
# 8            9       5-24-2017       Urban  12th Pass    BPL/Below ₹ 5,000
#
#   Vote_Now     Past_Vote  CM_satisfaction    MLA_satisfaction  age age_group  \
# 4    JD(U)  Did not vote  Fully Satisfied     Fully Satisfied   22     18-25
# 8      BJP           BJP  Fully Satisfied  Fully Dissatisfied   23     18-25
#
#   gender  assembly_no category    weight
# 4   Male          176       BC  0.333505
# 8   Male          181      Gen  0.226477

# %%
data1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
#          ********//////***********

# %%
data.tail()
# Out:
#       response_id collection_date urban_rural               education  \
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote     CM_satisfaction  \
# 6858  ₹ 10,000 - ₹ 20,000         RJD           RJD  Fully Dissatisfied
# 6859   ₹ 5,000 - ₹ 10,000  Left Front  Did not vote  Fully Dissatisfied
# 6861    BPL/Below ₹ 5,000         BJP           BJP  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000      JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000         BJP  Did not vote     Fully Satisfied
#
#         MLA_satisfaction  age  age_group gender  assembly_no category  \
# ...

# %%
#data=data[(data.age_group >= 18) & (data.age_group < 25)] ---sample formula

# %%
data2=data[(data.age_group >=25) & (data.age_group < 40)] # data2=data[(data.age_group>=25) & (data.age_group<40)] --- filtering with & operator

# %%
data2.head(2)                  # data2.head()
# Out:
# Empty DataFrame
# Columns: [response_id, collection_date, urban_rural, education, income, Vote_Now, Past_Vote, CM_satisfaction, MLA_satisfaction, age, age_group, gender, assembly_no, category, weight]
# Index: []

# %%
data2.age_group.unique()                       # data2.age_group.unique()
# Out:
# array([], dtype=int32)

# %%
data2['age_group']='25-40'                        # data2['age_group']='25-40'

# %%
data2.head(3)                        # data2.head(2)
# Out:
# Empty DataFrame
# Columns: [response_id, collection_date, urban_rural, education, income, Vote_Now, Past_Vote, CM_satisfaction, MLA_satisfaction, age, age_group, gender, assembly_no, category, weight]
# Index: []

# %%
data3=data[(data.age_group>=40) & (data.age_group<55)]                        # data3=data[(data.age_gruop>=40) & (data.age_group<55)]   ---filtering with and operator
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[275], line 1
# ----> 1 data3=data[(data.age_group>=40) & (data.age_group<55)]
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:62, in OpsMixin.__ge__(self, other)
#      60 @unpack_zerodim_and_defer("__ge__")
#      61 def __ge__(self, other):
# ---> 62     return self._cmp_method(other, operator.ge)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# ...

# %%
data3.head(2)                        # data3.head(2)
# Out:
# Empty DataFrame
# Columns: [response_id, collection_date, urban_rural, education, income, Vote_Now, Past_Vote, CM_satisfaction, MLA_satisfaction, age, age_group, gender, assembly_no, category, weight]
# Index: []

# %%
data3.age_group.unique()                        # data3.age_group.unique()
# Out:
# array([], dtype=int32)

# %%
data3['age_group']='40-55'                        # data3['age_group']='40-55'

# %%
data3.head(2)                            # data3.head(2)
# Out:
# Empty DataFrame
# Columns: [response_id, collection_date, urban_rural, education, income, Vote_Now, Past_Vote, CM_satisfaction, MLA_satisfaction, age, age_group, gender, assembly_no, category, weight]
# Index: []

# %%
data4=data[data.age_group>=55]         # data4=[(data.age_group>55)]       ----filtering on given condition basis

# %%
data4.head(2)                            # data4.head(2)
# Out:
# Empty DataFrame
# Columns: [response_id, collection_date, urban_rural, education, income, Vote_Now, Past_Vote, CM_satisfaction, MLA_satisfaction, age, age_group, gender, assembly_no, category, weight]
# Index: []

# %%
data4['age_group']='55+'                            # data4['age_group']='55+'

# %%
data4.head(2)                            # data4.head(2)
# Out:
# Empty DataFrame
# Columns: [response_id, collection_date, urban_rural, education, income, Vote_Now, Past_Vote, CM_satisfaction, MLA_satisfaction, age, age_group, gender, assembly_no, category, weight]
# Index: []

# %%
import pandas as pd

# %%
data=pd.concat([data1,data2,data3,data4])    # data=pd.concat([data1,data2,data3,data4])    ---for the concatenation of the dataframes

# %%
data
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# ...

# %%
data.age_group.unique()                                # data.age_group.unique()
# Out:
# array(['18-25'], dtype=object)

# %% [markdown]
# # Q 5:

# %% [markdown]
# # How many samples were collected for each age-group? Which age-group had the most sample?

# %%
data.head(2)                    # data.head(2)

# %%
data.age_group.value_counts()                    # data.age_group.value_counts()

# %% [markdown]
# # Q 6:

# %% [markdown]
# # What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions?

# %%
                        # survey.head(2)

# %%
                        # survey[survey['Vote_Now']=='RJD']   --FILTERING ON CONDITION BASIS
                        # survey[survey['Past_Vote']=='RJD']
                        # survey[(survey['Vote_Now']=='RJD') & (survey['Past_Vote']=='RJD']

# %%
                        # 811/6867*100  --calculate
